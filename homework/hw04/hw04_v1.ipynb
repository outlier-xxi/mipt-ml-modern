# %% [markdown]
# # Grokking at the Edge of Numerical Stability
#
# Запуск кода из репозитерия к статье: Grokking at the Edge of Numerical Stability
# - статья: https://arxiv.org/pdf/2501.04697
# - репозиторий: https://github.com/LucasPrietoAl/grokking-at-the-edge-of-numerical-stability

# %% [markdown]
# ## Запуск кода
#
# - Репозиторий не содержит артефактов какого-либо пакетного менеджера и не содержит requirements.txt
# - Requirements указаны в README.md, указаны:
#   - torch (без версии)
#   - numpy, pandas (с версиями)
# - Запуск обучения происходит через run_main_experiments.sh, который запускает python файл с параметрами:
#     ```shell
#     python grokking_experiments.py ...
#     ```
#
# Запустил не в ячейке, а в терминале, в byobu (обертка над tmux), чтобы запуск не повис при обрыве связи.
#
# Мои версии:
# - Python 3.12.3
# - torch 2.9.0

# %% [markdown]
# ```shell
# (ml-modern-hw03) lev@ripe-name-wanders-fin-02:~/project/ml-modern/homework/hw04/grokking-at-the-edge-of-numerical-stability$ ./run_main_experiments.sh
# Using device: cuda:0
# Starting training. Train dataset size: 5107, Test size: 7662
# Using AlgorithmicDataset
# stablemax
# /home/lev/project/ml-modern/homework/hw04/grokking-at-the-edge-of-numerical-stability/logger.py:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.metrics_df = pd.concat([self.metrics_df, pd.DataFrame(rows)], ignore_index=True)
# Epoch 0: Training loss: 4.7273
# Epoch 5000: Training loss: 0.0006
# Time taken for the last 5000 epochs: 0.31 min
# ...
# ...
# ...
# Time taken for the last 100 epochs: 0.00 min
# Epoch 8700: Training loss: 0.0002
# Time taken for the last 100 epochs: 0.00 min
# Epoch 8800: Training loss: 0.0002
# Time taken for the last 100 epochs: 0.00 min
# Epoch 8900: Training loss: 0.0002
# Time taken for the last 100 epochs: 0.00 min
# Epoch 9000: Training loss: 0.0002
# Time taken for the last 100 epochs: 0.00 min
# Epoch 9100: Training loss: 0.0002
# Time taken for the last 100 epochs: 0.00 min
# Epoch 9200: Training loss: 0.0002
# Time taken for the last 100 epochs: 0.00 min
# Epoch 9300: Training loss: 0.0002
# Time taken for the last 100 epochs: 0.00 min
# Epoch 9400: Training loss: 0.0001
# Time taken for the last 100 epochs: 0.00 min
# Epoch 9500: Training loss: 0.0001
# Time taken for the last 100 epochs: 0.00 min
# Epoch 9600: Training loss: 0.0001
# Time taken for the last 100 epochs: 0.00 min
# Epoch 9700: Training loss: 0.0001
# Time taken for the last 100 epochs: 0.00 min
# Epoch 9800: Training loss: 0.0001
# Time taken for the last 100 epochs: 0.00 min
# Epoch 9900: Training loss: 0.0001
# Time taken for the last 100 epochs: 0.00 min
# Test set: Average loss: 0.4557, Accuracy: 85.64
# Saving run: add_mod|num_epochs-10000|train_fraction-0.7|optimizer-SGD|log_frequency-100|lr-4.0|batch_size-8938|cross_entropy_dtype-float64|use_lr_scheduler-True
# (ml-modern-hw03) lev@ripe-name-wanders-fin-02:~/project/ml-modern/homework/hw04/grokking-at-the-edge-of-numerical-stability$ 1(ml-modern-hw03) lev@ripe-name-wanders-fin-02:~/project/ml-modern/homework/hw04/grokking-at-the-edge-of-numerical-stability$
# ```

# %%
from IPython.display import Image, display

display(Image(filename="/home/lev/project/ml-modern/homework/hw04/image/image.png"))
